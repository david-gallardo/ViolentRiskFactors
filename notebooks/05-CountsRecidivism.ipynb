# %% [markdown]
# # Counts Analysis with Recidivism Associations
#
# Co-occurrence of terms analysis: check how often pre-selected recidivism terms appear in abstracts with risk factor terms.
#
# This analysis searches through PubMed for papers that contain specified risk factors and selected association terms.
#
# Data extracted is the count of the number of papers with both terms. This is used to infer the associated terms for each risk factor.
#
# This notebook covers the recidivism-related association terms.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import normaltest, spearmanr

from lisc import Counts
from lisc.utils import SCDB, load_object
from lisc.io import load_txt_file
from lisc.plts.counts import plot_matrix, plot_clustermap, plot_dendrogram
# Out:
# /Users/davidgallardo-pujol/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import seaborn as sns
sns.set_context('talk')

# %%
# Import custom project code
import sys
sys.path.append('../code')
from plts import plot_count_hist, plot_time_associations, plot_latency_values
from analysis import get_time_associations

# %% [markdown]
# ## Setup

# %%
# Notebook settings
SAVE_FIG = True
SAVE_EXT = '.pdf'

# Set some plot settings for when saving out
#   This is because changing these looks a bit odd in the notebook
matrix_linewidths = 0.35 if SAVE_FIG else 0

# %%
# Analysis settings
# Minimum number of articles a risk factor must have to be represented

N_RISK_FACTORS = 1000

# %%
# Set the file locations
term_dir = '../terms/'
figs_dir = '../data/figures/counts'
db = SCDB('../')

# %%
# Set the name of the file to load
name = 'recidivism  '

# %%
# Load the counts object
counts = load_object('counts_' + name, directory=db)

# %% [markdown]
# ### Check Database Information
#
# Check the metadata about the data collection, including checking the database data were collected from.

# %%
# Check database information
counts.meta_data.db_info
# Out:
# {'dbname': 'pubmed',
#  'menuname': 'PubMed',
#  'description': 'PubMed bibliographic record',
#  'dbbuild': 'Build-2025.02.07.23.16',
#  'count': '38371236',
#  'lastupdate': '2025/02/07 23:16'}

# %%
# Check requester details
counts.meta_data.requester
# Out:
# {'n_requests': 414,
#  'wait_time': 0.3333333333333333,
#  'start_time': '15:49:13 Saturday 08 February 2025',
#  'end_time': '15:56:14 Saturday 08 February 2025',
#  'logging': None}

# %% [markdown]
# ## Collection Summaries

# %% [markdown]
# ### Risk Factor Articles

# %%
# Check the total number of risk factor papers
print('The total # of risk factor papers is: \t {:.0f}'.format(sum(counts.terms['A'].counts)))
# Out:
# The total # of risk factor papers is: 	 1411609

# %%
# Check the distribution of risk factor papers
print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
      *normaltest(np.log10(counts.terms['A'].counts))))
import os
if not os.path.exists(figs_dir):
    os.makedirs(figs_dir)

plot_count_hist(counts.terms['A'].counts, bins=12,
                save_fig=SAVE_FIG, file_name='riskfactor_hist' + SAVE_EXT,
                directory=figs_dir, save_kwargs={'transparent' : True})
# Out:
# Test for normality (log-spaced) 	 t-val: 0.23 	 p-val 0.89

# %% [markdown]
# ### Association Articles

# %%
# Check the total number of association papers
print('The total # of association papers is: \t {:.0f}'.format(sum(counts.terms['B'].counts)))
# Out:
# The total # of association papers is: 	 13757

# %%
# Check the total number of association papers
print('The total # of association papers is: \t {:.0f}'.format(sum(counts.terms['B'].counts)))

# Check the distribution of association papers
if len(counts.terms['B'].counts) >= 8:
    print('Test for normality (log-spaced) \t t-val: {:1.2f} \t p-val {:1.2f}'.format(\
          *normaltest(np.log10(counts.terms['B'].counts))))
else:
    print("Not enough samples to perform normality test (requires at least 8).")

plot_count_hist(counts.terms['B'].counts, bins=12,
                save_fig=SAVE_FIG, file_name=name + '_assoc_hist' + SAVE_EXT,
                directory=figs_dir, save_kwargs={'transparent' : True})
# Out:
# The total # of association papers is: 	 13757
# Not enough samples to perform normality test (requires at least 8).

# %% [markdown]
# ### Co-occurence Numbers

# %%
# Check how many co-occurence values are zero
n_coocs = np.multiply(*counts.counts.shape)
n_zero = sum(np.ravel(counts.counts) == 0)
percent_zero = (n_zero / n_coocs) * 100

# %%
# Print out completeness of the co-occurence matrix
print('Percent zero: \t\t% {:4.2f}'.format(percent_zero))
print('Percent non-zero: \t% {:4.2f}'.format(100 - percent_zero))
# Out:
# Percent zero: 		% 18.08
# Percent non-zero: 	% 81.92

# %%
# Print out summaries of the co-occurence data
print('The total number of cooc values is: \t{:d}'.format(sum(np.ravel(counts.counts))))
print('The median number of cooc values is: \t{:2.2f}'.format(np.median(np.ravel(counts.counts))))
# Out:
# The total number of cooc values is: 	5983
# The median number of cooc values is: 	6.00

# %%
# Plot the distribution of (non-zero) co-occurence values
plot_count_hist(np.ravel(counts.counts), bins=12, log=True)

# %% [markdown]
# # Check Counts

# %%
# Check the terms with the most papers
counts.check_top(dim='A')
counts.check_top(dim='B')
# Out:
# The most studied term is  'Depression'  with  418481  articles.
# The most studied term is  'sexual recidivism'  with  6120  articles.

# %%
# Check how many papers were found for each risk factor term
counts.check_counts(dim='A')
# Out:
# The number of documents found for each search term is:
#   'Single-parent family'              -      232
#   'Two-parent family'                 -     1208
#   'Extended family'                   -     2222
#   'Divorced parents'                  -      495
#   'Stable family'                     -      545
#   'Parental conflict'                 -     1223
#   'Lack of supervision'               -      712
#   'Emotional support'                 -    13215
#   'Family abuse'                      -      843
#   'External abuse'                    -     9873
#   'Low income'                        -    74226
#   'Large family'                      -     7408
#   'Antisocial thoughts'               -      974
#   'Moral reasoning'                   -     1875
#   'Individualistic attitudes'         -     4431
#   'Prosocial attitudes'               -     3108
#   'Antisocial attitudes'              -      139
#   'Self-preservation beliefs'         -     1591
#   'Prosocial beliefs'                 -      855
#   'Distorted beliefs'                 -     3355
#   'Individualistic values'            -      210
#   'Prosocial values'                  -     9762
#   'Antisocial values'                 -     2734
#   'Hostility'                         -    79931
#   'Anger states'                      -    18164
#   'Criminal neighborhood'             -     4335
#   'Childhood violence'                -     2869
#   'Antisocial peers'                  -     3944
#   'Debt'                              -    20028
#   'Educational attainment'            -    18517
#   'Vocational skills'                 -     2082
#   'Unemployment'                      -    13834
#   'Work instability'                  -     1182
#   'Prenatal tobacco exposure'         -     3901
#   'Prenatal alcohol exposure'         -     1920
#   'Prenatal drug exposure'            -      698
#   'Alcohol use'                       -    80907
#   'Drug use'                          -    73153
#   'Impulsivity'                       -    12870
#   'Lack of empathy'                   -     1238
#   'Dark traits'                       -     4352
#   'Attachment style'                  -     2754
#   'Aggressiveness'                    -    19745
#   'Sensation-seeking'                 -     6681
#   'Antisocial personality disorder'   -    11003
#   'Personality disorder'              -    18663
#   'Psychosis'                         -    32532
#   'Anxiety'                           -   263090
#   'Depression'                        -   418481
#   'Extraversion'                      -    13024
#   'Neuroticism'                       -    37913
#   'Agreeableness'                     -     4642
#   'Conscientiousness'                 -    66734
#   'Openness'                          -    10164
#   'Early antisocial behavior'         -       63
#   'Parental incarceration'            -      228
#   'Antisocial history'                -     1520
#   'Unstructured activities'           -    18871
#   'Antisocial recreation'             -      340

# %%
# Check how many papers were found for each association term
counts.check_counts(dim='B')
# Out:
# The number of documents found for each search term is:
#   'violent recidivism'   -   2286
#   'general recidivism'   -   5351
#   'sexual recidivism'    -   6120

# %%
# Check the most commonly associated association term for each risk factor
counts.check_data()
# Out:
# For  'Single-parent family'             the highest association is  'violent recidivism'  with           1
# For  'Two-parent family'                the highest association is  'violent recidivism'  with           2
# For  'Extended family'                  the highest association is  'violent recidivism'  with           2
# For  'Divorced parents'                 the highest association is  'general recidivism'  with           1
# For  'Stable family'                    the highest association is  'violent recidivism'  with           2
# For  'Parental conflict'                the highest association is  'violent recidivism'  with           2
# For  'Lack of supervision'              the highest association is  'general recidivism'  with           2
# For  'Emotional support'                the highest association is  'sexual recidivism'   with          11
# For  'Family abuse'                     the highest association is  'general recidivism'  with           8
# For  'External abuse'                   the highest association is  'general recidivism'  with          52
# For  'Low income'                       the highest association is  'general recidivism'  with          51
# For  'Large family'                     the highest association is  'general recidivism'  with           3
# For  'Antisocial thoughts'              the highest association is  'general recidivism'  with          27
# For  'Moral reasoning'                  the highest association is  'general recidivism'  with          10
# For  'Individualistic attitudes'        the highest association is  'general recidivism'  with           3
# For  'Prosocial attitudes'              the highest association is  'general recidivism'  with           4
# For  'Antisocial attitudes'             the highest association is  'general recidivism'  with          11
# For  'Self-preservation beliefs'        the highest association is  'violent recidivism'  with           0
# For  'Prosocial beliefs'                the highest association is  'violent recidivism'  with           0
# For  'Distorted beliefs'                the highest association is  'general recidivism'  with          23
# For  'Individualistic values'           the highest association is  'general recidivism'  with           1
# For  'Prosocial values'                 the highest association is  'general recidivism'  with           6
# For  'Antisocial values'                the highest association is  'general recidivism'  with         138
# For  'Hostility'                        the highest association is  'general recidivism'  with         205
# For  'Anger states'                     the highest association is  'violent recidivism'  with          12
# For  'Criminal neighborhood'            the highest association is  'general recidivism'  with          65
# For  'Childhood violence'               the highest association is  'violent recidivism'  with          28
# For  'Antisocial peers'                 the highest association is  'general recidivism'  with         195
# For  'Debt'                             the highest association is  'general recidivism'  with           8
# For  'Educational attainment'           the highest association is  'general recidivism'  with          17
# For  'Vocational skills'                the highest association is  'general recidivism'  with           4
# For  'Unemployment'                     the highest association is  'general recidivism'  with          38
# For  'Work instability'                 the highest association is  'general recidivism'  with           2
# For  'Prenatal tobacco exposure'        the highest association is  'violent recidivism'  with           2
# For  'Prenatal alcohol exposure'        the highest association is  'general recidivism'  with           3
# For  'Prenatal drug exposure'           the highest association is  'violent recidivism'  with           0
# For  'Alcohol use'                      the highest association is  'general recidivism'  with         275
# For  'Drug use'                         the highest association is  'general recidivism'  with         479
# For  'Impulsivity'                      the highest association is  'general recidivism'  with          75
# For  'Lack of empathy'                  the highest association is  'general recidivism'  with          12
# For  'Dark traits'                      the highest association is  'general recidivism'  with         227
# For  'Attachment style'                 the highest association is  'violent recidivism'  with           1
# For  'Aggressiveness'                   the highest association is  'general recidivism'  with          51
# For  'Sensation-seeking'                the highest association is  'general recidivism'  with          16
# For  'Antisocial personality disorder'  the highest association is  'general recidivism'  with         298
# For  'Personality disorder'             the highest association is  'general recidivism'  with         171
# For  'Psychosis'                        the highest association is  'general recidivism'  with          75
# For  'Anxiety'                          the highest association is  'sexual recidivism'   with         168
# For  'Depression'                       the highest association is  'sexual recidivism'   with         285
# For  'Extraversion'                     the highest association is  'general recidivism'  with          14
# For  'Neuroticism'                      the highest association is  'sexual recidivism'   with          33
# For  'Agreeableness'                    the highest association is  'general recidivism'  with           4
# For  'Conscientiousness'                the highest association is  'general recidivism'  with          79
# For  'Openness'                         the highest association is  'general recidivism'  with           4
# For  'Early antisocial behavior'        the highest association is  'general recidivism'  with           3
# For  'Parental incarceration'           the highest association is  'general recidivism'  with           5
# For  'Antisocial history'               the highest association is  'general recidivism'  with         104
# For  'Unstructured activities'          the highest association is  'general recidivism'  with          10
# For  'Antisocial recreation'            the highest association is  'general recidivism'  with           4

# %%
# Check the most commonly associated risk factor for each term
counts.check_data(dim='B')
# Out:
# For  'violent recidivism'  the highest association is  'Drug use'                         with         192
# For  'general recidivism'  the highest association is  'Drug use'                         with         479
# For  'sexual recidivism'   the highest association is  'Depression'                       with         285

# %% [markdown]
# ## Select risk factors with enough articles

# %%
# Check how many risk factors currently
counts.terms['A'].n_terms
# Out:
# 59

# %%
# Drop ERPs without a target number of articles
counts.drop_data(N_RISK_FACTORS, dim='A')
print(counts.terms['A'].n_terms)
# Out:
# 46

# %% [markdown]
# ## Group Level Plots

# %%
# Compute the normalized score (percent association)
counts.compute_score('normalize', dim='A')

# %%
# Plot the matrix of percent associations - risk factors & terms
plot_matrix(counts, linewidths=matrix_linewidths, figsize=(10, 8),
            save_fig=SAVE_FIG, file_name=name + '_associations' + SAVE_EXT,
            directory=figs_dir, save_kwargs={'transparent' : True})

# %%
import numpy as np
print("NaN en la matriu?", np.isnan(counts.score).any())
print("Inf en la matriu?", np.isinf(counts.score).any())

counts.score = np.nan_to_num(counts.score, nan=0.0, posinf=1e10, neginf=-1e10)


# Plot a clustermap, clustering risk factors and terms based on similarity
plot_clustermap(counts, attribute='score', cmap='blue', metric='euclidean',
                linewidths=matrix_linewidths, figsize=(12, 10),
                save_fig=SAVE_FIG, file_name=name + '_clustermap' + SAVE_EXT,
                directory=figs_dir, save_kwargs={'transparent' : True})
# Out:
# NaN en la matriu? False
# Inf en la matriu? False

# %% [markdown]
# ### Similarity Measure

# %%
# Calculate similarity between all risk factors (based on term association percents)
counts.compute_score('similarity', 'A')
# Out:
# /Users/davidgallardo-pujol/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/lisc/analysis/counts.py:121: RuntimeWarning: divide by zero encountered in divide
#   inv_square_mag = 1 / np.diag(similarity)

# %%
# Plot similarity matrix between risk factors
plot_matrix(counts, linewidths=matrix_linewidths, figsize=(10, 7),
            save_fig=SAVE_FIG, file_name=name + '_similarity' + SAVE_EXT,
            directory=figs_dir, save_kwargs={'transparent' : True})

# %%
# Plot a clustermap, clustering risk factors based on similarity
plot_clustermap(counts, attribute='score', cmap='blue', 
                metric='euclidean',  # Afegir aquest argument
                linewidths=matrix_linewidths, figsize=(12, 10),
                save_fig=SAVE_FIG, file_name=name + '_similarity_cluster' + SAVE_EXT,
                directory=figs_dir, save_kwargs={'transparent' : True})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Plot a clustermap, clustering risk factors based on similarity
# ----> 2 plot_clustermap(counts, attribute='score', cmap='blue',
#       3                 linewidths=matrix_linewidths, figsize=(12, 10),
#       4                 save_fig=SAVE_FIG, file_name=name + '_similarity_cluster' + SAVE_EXT,
#       5                 directory=figs_dir, save_kwargs={'transparent' : True})
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/lisc/plts/utils.py:177, in savefig.<locals>.decorated(*args, **kwargs)
#     174 if isinstance(file_path, SCDB):
#     175     file_path = file_path.get_folder_path('figures')
# --> 177 func(*args, **kwargs)
#     179 if save_fig:
#     180     save_figure(file_name, file_path, close, **save_kwargs)
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/lisc/plts/counts.py:177, in plot_clustermap(data, x_labels, y_labels, attribute, transpose, method, metric, cmap, **kwargs)
#     174 data, x_labels, y_labels = counts_data_helper(data, x_labels, y_labels, attribute, transpose)
#     176 with sns.plotting_context("notebook", font_scale=kwargs.pop('font_scale', 1.0)):
# --> 177     cg = sns.clustermap(data, method=method, metric=metric,
#     178                         cmap=cmap, figsize=kwargs.pop('figsize', None),
#     179                         **check_args(['xticklabels', 'yticklabels'], x_labels, y_labels),
#     180                         **kwargs)
#     182 _ = plt.setp(cg.ax_heatmap.xaxis.get_majorticklabels(), rotation=60, ha='right')
#     183 _ = plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:1258, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
#    1254                       z_score=z_score, standard_scale=standard_scale,
#    1255                       mask=mask, dendrogram_ratio=dendrogram_ratio,
#    1256                       colors_ratio=colors_ratio, cbar_pos=cbar_pos)
# -> 1258 return plotter.plot(metric=metric, method=method,
#    1259                     colorbar_kws=cbar_kws,
#    1260                     row_cluster=row_cluster, col_cluster=col_cluster,
#    1261                     row_linkage=row_linkage, col_linkage=col_linkage,
#    1262                     tree_kws=tree_kws, **kwargs)
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:1129, in ClusterGrid.plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1125     kws.pop("square")
#    1127 colorbar_kws = {} if colorbar_kws is None else colorbar_kws
# -> 1129 self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1130                       row_linkage=row_linkage, col_linkage=col_linkage,
#    1131                       tree_kws=tree_kws)
#    1132 try:
#    1133     xind = self.dendrogram_col.reordered_ind
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:974, in ClusterGrid.plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#     970 def plot_dendrograms(self, row_cluster, col_cluster, metric, method,
#     971                      row_linkage, col_linkage, tree_kws):
#     972     # Plot the row dendrogram
#     973     if row_cluster:
# --> 974         self.dendrogram_row = dendrogram(
#     975             self.data2d, metric=metric, method=method, label=False, axis=0,
#     976             ax=self.ax_row_dendrogram, rotate=True, linkage=row_linkage,
#     977             tree_kws=tree_kws
#     978         )
#     979     else:
#     980         self.ax_row_dendrogram.set_xticks([])
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:687, in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     684 if _no_scipy:
#     685     raise RuntimeError("dendrogram requires scipy to be installed")
# --> 687 plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     688                              metric=metric, method=method,
#     689                              label=label, rotate=rotate)
#     690 if ax is None:
#     691     ax = plt.gca()
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:495, in _DendrogramPlotter.__init__(self, data, linkage, metric, method, axis, label, rotate)
#     492 self.rotate = rotate
#     494 if linkage is None:
# --> 495     self.linkage = self.calculated_linkage
#     496 else:
#     497     self.linkage = linkage
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:562, in _DendrogramPlotter.calculated_linkage(self)
#     558         msg = ("Clustering large matrix with scipy. Installing "
#     559                "`fastcluster` may give better performance.")
#     560         warnings.warn(msg)
# --> 562 return self._calculate_linkage_scipy()
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/seaborn/matrix.py:530, in _DendrogramPlotter._calculate_linkage_scipy(self)
#     529 def _calculate_linkage_scipy(self):
# --> 530     linkage = hierarchy.linkage(self.array, method=self.method,
#     531                                 metric=self.metric)
#     532     return linkage
#
# File ~/Documents/GitHub/ViolentRiskFactors/.venv/lib/python3.9/site-packages/scipy/cluster/hierarchy.py:1030, in linkage(y, method, metric, optimal_ordering)
#    1027     raise ValueError("`y` must be 1 or 2 dimensional.")
#    1029 if not xp.all(xp.isfinite(y)):
# -> 1030     raise ValueError("The condensed distance matrix must contain only "
#    1031                      "finite values.")
#    1033 n = int(distance.num_obs_y(y))
#    1034 method_code = _LINKAGE_METHODS[method]
#
# ValueError: The condensed distance matrix must contain only finite values.

# %% [markdown]
# ### Association Score

# %%
# Calculate association between all ERPs
counts.compute_score('association')

# %%
# Plot similarity matrix between terms
plot_matrix(counts, linewidths=matrix_linewidths, figsize=(10, 7),
            save_fig=SAVE_FIG, file_name=name + '_associations' + SAVE_EXT,
            directory=figs_dir, save_kwargs={'transparent' : True})

# %% [markdown]
# ### Dendrograms

# %%
# Plot dendrogram of risk factors, based on percent associations with terms
plot_dendrogram(counts, attribute='score', figsize=(6, 8),
                save_fig=SAVE_FIG, file_name=name + '_erp_dendro' + SAVE_EXT,
                directory=figs_dir, save_kwargs={'transparent' : True})

# %%
# Plot dendrogram of termss, based on percent associations with risk factors
plot_dendrogram(counts, attribute='score', transpose=True, figsize=(6, 8),
                save_fig=SAVE_FIG, file_name=name + '_term_dendro' + SAVE_EXT,
                directory=figs_dir, save_kwargs={'transparent' : True})
